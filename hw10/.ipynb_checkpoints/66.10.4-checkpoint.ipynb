# %%
data = read.csv('housing.data.txt',sep = '',header = FALSE)

# %% [markdown]
#    1. CRIM      per capita crime rate by town
#     2. ZN        proportion of residential land zoned for lots over
#                  25,000 sq.ft.
#     3. INDUS     proportion of non-retail business acres per town
#     4. CHAS      Charles River dummy variable (= 1 if tract bounds
#                  river; 0 otherwise)
#     5. NOX       nitric oxides concentration (parts per 10 million)
#     6. RM        average number of rooms per dwelling
#     7. AGE       proportion of owner-occupied units built prior to 1940
#     8. DIS       weighted distances to five Boston employment centres
#     9. RAD       index of accessibility to radial highways
#     10. TAX      full-value property-tax rate per $10,000
#     11. PTRATIO  pupil-teacher ratio by town
#     12. B        1000(Bk - 0.63)^2 where Bk is the proportion of blacks
#                  by town
#     13. LSTAT    % lower status of the population
#     14. MEDV     Median value of owner-occupied homes in $1000's

# %%
require(graphics)

attach(spline)
plot(data$V6, data$V14, main = "MEDV(RM)")
spline.spl <- smooth.spline(data$V6, data$V14)
lines(spline.spl, col = "blue")
nadwat.spl <- ksmooth(data$V6, data$V14)
lines(nadwat.spl, col = "red")
legend('topleft', c('smooth spline','Nadaraya–Watson'), 
   lty=1, col=c('blue', 'red'), bty='n', cex=.75)
detach()
# Out:
# The following object is masked _by_ .GlobalEnv:
#
#     data
#
# The following objects are masked from spline (pos = 3):
#
#     call, crit, cv.crit, data, df, fit, iparms, lambda, lev, pen.crit,
#     spar, w, x, y, yin
#
# The following objects are masked from spline (pos = 4):
#
#     call, crit, cv.crit, data, df, fit, iparms, lambda, lev, pen.crit,
#     spar, w, x, y, yin
#
# The following objects are masked from spline (pos = 5):
#
#     call, crit, cv.crit, data, df, fit, iparms, lambda, lev, pen.crit,
#     spar, w, x, y, yin
#
# The following objects are masked from spline (pos = 6):
#
#     call, crit, cv.crit, data, df, fit, iparms, lambda, lev, pen.crit,
#     spar, w, x, y, yin
#
# The following objects are masked from spline (pos = 7):
#
#     call, crit, cv.crit, data, df, fit, iparms, lambda, lev, pen.crit,
#     spar, w, x, y, yin
#
# The following objects are masked from spline (pos = 8):
#
#     call, crit, cv.crit, data, df, fit, iparms, lambda, lev, pen.crit,
#     spar, w, x, y, yin
#
# The following objects are masked from spline (pos = 9):
#
#     call, crit, cv.crit, data, df, fit, iparms, lambda, lev, pen.crit,
#     spar, w, x, y, yin
#
# The following objects are masked from spline (pos = 10):
#
#     call, crit, cv.crit, data, df, fit, iparms, lambda, lev, pen.crit,
#     spar, w, x, y, yin
#
# The following objects are masked from spline (pos = 11):
#
#     call, crit, cv.crit, data, df, fit, iparms, lambda, lev, pen.crit,
#     spar, w, x, y, yin
#
# The following objects are masked from spline (pos = 12):
#
#     call, crit, cv.crit, data, df, fit, iparms, lambda, lev, pen.crit,
#     spar, w, x, y, yin
#
# The following objects are masked from spline (pos = 13):
#
#     call, crit, cv.crit, data, df, fit, iparms, lambda, lev, pen.crit,
#     spar, w, x, y, yin
#
# The following objects are masked from spline (pos = 14):
#
#     call, crit, cv.crit, data, df, fit, iparms, lambda, lev, pen.crit,
#     spar, w, x, y, yin
#
# The following objects are masked from spline (pos = 15):
#
#     call, crit, cv.crit, data, df, fit, iparms, lambda, lev, pen.crit,
#     spar, w, x, y, yin
#
# The following objects are masked from spline (pos = 16):
#
#     call, crit, cv.crit, data, df, fit, iparms, lambda, lev, pen.crit,
#     spar, w, x, y, yin
#
# The following objects are masked from spline (pos = 17):
#
#     call, crit, cv.crit, data, df, fit, iparms, lambda, lev, pen.crit,
#     spar, w, x, y, yin
#
# The following objects are masked from spline (pos = 18):
#
#     call, crit, cv.crit, data, df, fit, iparms, lambda, lev, pen.crit,
#     spar, w, x, y, yin
#
# The following objects are masked from spline (pos = 19):
#
#     call, crit, cv.crit, data, df, fit, iparms, lambda, lev, pen.crit,
#     spar, w, x, y, yin
#
# The following objects are masked from spline (pos = 20):
#
#     call, crit, cv.crit, data, df, fit, iparms, lambda, lev, pen.crit,
#     spar, w, x, y, yin
#
# Warning message in strwidth(legend, units = "user", cex = cex, font = text.font):
# “ошибка конвертации 'Nadaraya–Watson' в 'mbcsToSbcs': точка заменена на <e2>”Warning message in strwidth(legend, units = "user", cex = cex, font = text.font):
# “ошибка конвертации 'Nadaraya–Watson' в 'mbcsToSbcs': точка заменена на <80>”Warning message in strwidth(legend, units = "user", cex = cex, font = text.font):
# “ошибка конвертации 'Nadaraya–Watson' в 'mbcsToSbcs': точка заменена на <93>”Warning message in text.default(x, y, ...):
# “ошибка конвертации 'Nadaraya–Watson' в 'mbcsToSbcs': точка заменена на <e2>”Warning message in text.default(x, y, ...):
# “ошибка конвертации 'Nadaraya–Watson' в 'mbcsToSbcs': точка заменена на <80>”Warning message in text.default(x, y, ...):
# “ошибка конвертации 'Nadaraya–Watson' в 'mbcsToSbcs': точка заменена на <93>”
# Plot with title “MEDV(RM)”

# %% [markdown]
# $SS(h) = \sum (Y_i - m(X_i))^2 + h \int_{X_{(1)}}^{X_{(n)}} [m^{''}(x)]^2 dx \to \min_m$
#
# второе слагаемое в сглаживающем сплайне нужен для ограничения вариации аппроксимирующей функции. При $h \to 0$ получим кривую, обращающую SS(h) в ноль, так как она сможет идеально проходить через все $Y_i$. Если же $h \to \infty$, то основной штраф будет за вариацию, то есть алгоритм выберет какую то прямую (точнее говоря метод превратится в МНК). Видимо оптимальнее всего брать $h \sim \frac{ \overline{(y_i - \hat{y_{i_{MSE}}}}}{  \overline{ \frac{\Delta \frac{\Delta y_i}{\Delta x_i}}{\Delta x_i}}}$ (примерно такого порядка, чтобы вклады обоих слагаемых были соизмеримы)
#
# при построении сплайна использовалось дефолтное h =
